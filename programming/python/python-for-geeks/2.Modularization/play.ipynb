# %%
import sys

# %%
sys.platform
# Out:
# 'linux'

# %%
print(__name__)
# Out:
# __main__

# %%
import play as ps
ps.my_main()
# Out:
# Playing module: play

# %%
play_mod = __import__('play')
play_mod.my_main()
# Out:
# Playing module: play
